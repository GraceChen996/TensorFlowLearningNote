# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceChen996/TensorFlowLearningNote/blob/branch1/%E7%BA%BF%E6%80%A7%E5%9B%9E%E5%BD%92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print('Tensorflow version'.format(tf.__version__))
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Tensorflow version

# %%
import pandas as pd

# %%
data = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')

# %%
data
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 2           1  female  26.0                   0      0   7.9250   Third
# 3           1  female  35.0                   1      0  53.1000   First
# 4           0    male  28.0                   0      0   8.4583   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 622         0    male  28.0                   0      0  10.5000  Second
# 623         0    male  25.0                   0      0   7.0500   Third
# 624         1  female  19.0                   0      0  30.0000   First
# 625         0  female  28.0                   1      2  23.4500   Third
# 626         0    male  32.0                   0      0   7.7500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(data.age,data.fare)

# %%
x = data.age
y = data.fare

# %%
model = tf.keras.Sequential() #建立序贯模型
model.add(tf.keras.layers.Dense(1,input_shape=(1,)))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
#对model进行编译(配置)
model.compile(
    optimizer='adam',
    loss='mse'
)

# %%
history = model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 1s 2ms/step - loss: 5390.1152
# Epoch 2/500
# 20/20 [==============================] - 0s 2ms/step - loss: 5326.9419
# Epoch 3/500
# 20/20 [==============================] - 0s 2ms/step - loss: 5264.3364
# Epoch 4/500
# 20/20 [==============================] - 0s 2ms/step - loss: 5203.5586
# Epoch 5/500
# 20/20 [==============================] - 0s 3ms/step - loss: 5144.6660
# Epoch 6/500
# 20/20 [==============================] - 0s 2ms/step - loss: 5084.7793
# Epoch 7/500
# 20/20 [==============================] - 0s 2ms/step - loss: 5029.4380
# Epoch 8/500
# 20/20 [==============================] - 0s 2ms/step - loss: 4973.1431
# Epoch 9/500
# 20/20 [==============================] - 0s 2ms/step - loss: 4919.1504
# Epoch 10/500
# 20/20 [==============================] - 0s 2ms/step - loss: 4865.0459
# Epoch 11/500
# 20/20 [==============================] - 0s 2ms/step - loss: 4814.2026
# Epoch 12/500
# ...
